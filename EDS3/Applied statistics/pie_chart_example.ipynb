# %%
import matplotlib.pyplot as plt

# %%
# Labeling
labels = ['apple', 'blueberry', 'orange']

# %%
# Data
sizes = [100, 70, 30]

# %%
# Creating plot
fig, ax = plt.subplots()
ax.pie(sizes, labels = labels, autopct = '%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x19693bc2510>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'apple'),
#   Text(-0.49938956806635254, -0.9801071672559598, 'blueberry'),
#   Text(0.9801071672559598, -0.4993895680663526, 'orange')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-0.2723943098543741, -0.5346039094123416, '35.0%'),
#   Text(0.5346039094123416, -0.27239430985437413, '15.0%')])
